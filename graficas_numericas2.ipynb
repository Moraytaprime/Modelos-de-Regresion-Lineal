# %% [markdown]
# <a href="https://colab.research.google.com/github/Moraytaprime/Modelos-de-Regresion-Lineal/blob/main/graficas_numericas2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importamos librerías requeridas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Instalamos librería para análisis de variables categóricas
# %pip install funpymodeling

# %%
from funpymodeling.exploratory import freq_tbl

# %%
#Cargar archivo csv desde equipo
from google.colab import files
files.upload()

# %%
#Ajustar maximo de filas
pd.options.display.max_rows= None
pd.options.display.max_columns= None

# %%
#Carga desde un archivo .csv sin indice y con decodificación. Ejemplos: 'ascii', 'UTF-8'
df = pd.read_csv("DataframeEquipo3Procesado.csv")
df.head(30)
# Out:
#     Unnamed: 0      Marca temporal Nombre del estudiante entrevistador  \
# 0            0  2/11/2023 19:14:21         Eduardo Yael Tomas Chapital
# 1            1  3/11/2023 13:04:08       Josue Nicolás Perez Villegas
# 2            2  3/11/2023 13:09:02            Alan De La Fuente Pérez
# 3            3  3/11/2023 13:09:03       Josue Nicolás Perez Villegas
# 4            4  3/11/2023 13:13:56        Josue Nicolás Perez Villegas
# 5            5  3/11/2023 13:15:20            Alan De La Fuente Pérez
# 6            6  3/11/2023 13:20:24             Alan De La Fuente Perez
# 7            7  3/11/2023 13:25:34           Jose Miguel Gomez Morayta
# 8            8  3/11/2023 13:33:43       Josue Nicolás Perez Villegas
# 9            9  3/11/2023 15:56:29              Francisco García Uicab
# 10          10  5/11/2023 12:22:12                       Omar Jiménez
# 11          11  5/11/2023 12:32:40                       Omar Jiménez
# ...

# %%
df.iloc[:,[28]]

# %%
df['Equipo del entrevistador'] = df['Equipo del entrevistador'].astype(str)
df['¿Cuántos clientes, en promedio, recibe en un día entre semana?'] = df['¿Cuántos clientes, en promedio, recibe en un día entre semana?'].astype(str)
df['¿Cuántos clientes, en promedio, recibe en un día del fin de semana?'] = df['¿Cuántos clientes, en promedio, recibe en un día del fin de semana?'].astype(str)
df['¿Cuántos productos aproximadamente maneja en su tienda?'] = df['¿Cuántos productos aproximadamente maneja en su tienda?'].astype(str)
df['En caso de tener un sistema de recolección ¿Cada cuánto pasa el camión de la basura por su negocio?'] = df['En caso de tener un sistema de recolección ¿Cada cuánto pasa el camión de la basura por su negocio?'].astype(str)
df['En una escala de 1 a 10, ¿cómo evaluaría sus esfuerzos para reducir su impacto ambiental?'] = df['En una escala de 1 a 10, ¿cómo evaluaría sus esfuerzos para reducir su impacto ambiental?'].astype(str)
df['En una escala de 1 a 10, ¿cómo evaluaría sus esfuerzos para reducir su impacto social?'] = df['En una escala de 1 a 10, ¿cómo evaluaría sus esfuerzos para reducir su impacto social?'].astype(str)

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(df.iloc[:,[28]])

#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table1[table1['frequency']>1]
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('Equipo del entrevistador')

#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(df.iloc[:,[29]])

#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table1[table1['frequency']>1]
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('¿Cuántos clientes, en promedio, recibe en un día entre semana?')

#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(df.iloc[:,[30]])

#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table1[table1['frequency']>1]
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('¿Cuántos clientes, en promedio, recibe en un día del fin de semana?')

#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(df.iloc[:,[31]])

#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table1[table1['frequency']>1]
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('¿Cuántos productos aproximadamente maneja en su tienda?')

#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(df.iloc[:,[32]])

#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table1[table1['frequency']>1]
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('En caso de tener un sistema de recolección ¿Cada cuánto pasa el camión de la basura por su negocio?')

#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(df.iloc[:,[33]])

#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table1[table1['frequency']>1]
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('En una escala de 1 a 10, ¿cómo evaluaría sus esfuerzos para reducir su impacto ambiental?')

#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(df.iloc[:,[34]])

#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table1[table1['frequency']>1]
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('En una escala de 1 a 10, ¿cómo evaluaría sus esfuerzos para reducir su impacto social?')

#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
dfNEW=df.iloc[:,[29,30,31,32,33,34,35]]
dfNEW
# Out:
#       Equipo del entrevistador  \
# 0                          4.0
# 1                          3.0
# 2                          3.0
# 3                          3.0
# 4                          3.0
# 5                          3.0
# 6                          3.0
# 7                          3.0
# 8                          3.0
# 9                          2.0
# 10                         1.0
# 11                         1.0
# 12                         1.0
# 13                         1.0
# 14                         1.0
# 15                         1.0
# 16                         1.0
# 17                         1.0
# 18                         1.0
# 19                         0.0
# 20                         2.0
# 21                         2.0
# 22                         2.0
# 23                         2.0
# 24                         2.0
# 25                         2.0
# 26                         2.0
# 27                         2.0
# 28                         2.0
# ...

# %%
#Encontramos todas las correlaciones entre las variables
Corr_Factors=dfNEW.corr()
Corr_Factors

# %%
#Encontramos el valor absoluto de todas las correlaciones entre las variables
Corr_Factors1= abs(Corr_Factors)
Corr_Factors1

# %%
#Graficamos el mapa de calor de los coeficientes de correlación
Heat_Map= sns.heatmap(Corr_Factors1, cmap = 'coolwarm')
Heat_Map
# Out:
# <Axes: >

# %% [markdown]
# RECOLOR DEL MAPA Y ELECCION DE VARIABLES CON MAYOR CORRELACION

# %%
#Ajustamos el mapa de calor de los coeficientes de correlación
Heat_Map= sns.heatmap(Corr_Factors1, cmap = 'YlGnBu', annot=True, fmt=".2f")
Heat_Map
# Out:
# <Axes: >

# %%
#Graficamos todas las dispersiones entre todas las variables
sns.pairplot(dfNEW)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# ...

# %% [markdown]
# Graficas para sacar regresion lineal multiple

# %% [markdown]
# Dato 1

# %%
sns.scatterplot(x='En una escala de 1 a 10, ¿cómo evaluaría sus esfuerzos para reducir su impacto social?', y='Equipo del entrevistador', color="blue", data=df)
sns.scatterplot(x='En caso de tener un sistema de recolección ¿Cada cuánto pasa el camión de la basura por su negocio?', y='Equipo del entrevistador', color="red", data=df)
sns.scatterplot(x='¿Cuántos clientes, en promedio, recibe en un día entre semana?', y='Equipo del entrevistador', color="yellow", data=df)

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep1= df[['En una escala de 1 a 10, ¿cómo evaluaría sus esfuerzos para reducir su impacto social?', 'En caso de tener un sistema de recolección ¿Cada cuánto pasa el camión de la basura por su negocio?','¿Cuántos clientes, en promedio, recibe en un día entre semana?']]
Var_Dep1= df['Equipo del entrevistador']

# %%
#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model1= LinearRegression()

# %%
#Ajustamos el modelo con las variables antes declaradas
model1.fit(X=Vars_Indep1, y=Var_Dep1)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# ...

# %%
#Verificamos los coeficientes obtenidos para el modelo ajustado
model1.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['En una escala de 1 a 10, ¿cómo evaluaría sus esfuerzos para reducir su impacto social?',
#         'En caso de tener un sistema de recolección ¿Cada cuánto pasa el camión de la basura por su negocio?',
#         '¿Cuántos clientes, en promedio, recibe en un día entre semana?'],
#        dtype=object),
#  'n_features_in_': 3,
#  'coef_': array([-0.04702074, -0.13658917,  0.00129163]),
#  'rank_': 3,
#  'singular_': array([1352.21097784,   85.56882513,   62.92344093]),
#  'intercept_': 3.492032086146843}

# %% [markdown]
# y=-0.04702074X1 -0.13658917X2 +0.00129163X3+3.492032086146843

# %%
#Predecimos los valores de total de accidentes a partir de las variables: "alcohol", "speeding" y "no_previous"
y_pred1= model1.predict(X=df[['En una escala de 1 a 10, ¿cómo evaluaría sus esfuerzos para reducir su impacto social?', 'En caso de tener un sistema de recolección ¿Cada cuánto pasa el camión de la basura por su negocio?','¿Cuántos clientes, en promedio, recibe en un día entre semana?']])
y_pred1
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# array([3.11844939, 3.22384063, 2.89435287, ..., 2.80031138, 3.15461494,
#        3.11223853])

# %%
#Insertamos la columna de predicciones en el DataFrame
df.insert(0, 'Predicciones1', y_pred1)
df

# %%
sns.scatterplot(x='En una escala de 1 a 10, ¿cómo evaluaría sus esfuerzos para reducir su impacto social?', y='Equipo del entrevistador', color="blue", data=df)

sns.scatterplot(x='En una escala de 1 a 10, ¿cómo evaluaría sus esfuerzos para reducir su impacto social?', y='Predicciones1', color="yellow", data=df)

# %%
sns.scatterplot(x='En caso de tener un sistema de recolección ¿Cada cuánto pasa el camión de la basura por su negocio?', y='Equipo del entrevistador', color="purple", data=df)

sns.scatterplot(x='En caso de tener un sistema de recolección ¿Cada cuánto pasa el camión de la basura por su negocio?', y='Predicciones1', color="yellow", data=df)

# %%
sns.scatterplot(x='¿Cuántos clientes, en promedio, recibe en un día entre semana?', y='Equipo del entrevistador', color="red", data=df)
sns.scatterplot(x='¿Cuántos clientes, en promedio, recibe en un día entre semana?', y='Predicciones1', color="yellow", data=df)

# %% [markdown]
# DATO 2

# %%
sns.scatterplot(x='¿Cuántos clientes, en promedio, recibe en un día del fin de semana?', y='¿Cuántos clientes, en promedio, recibe en un día entre semana?', color="blue", data=df)
sns.scatterplot(x='Equipo del entrevistador', y='¿Cuántos clientes, en promedio, recibe en un día entre semana?', color="red", data=df)

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep2= df[['¿Cuántos clientes, en promedio, recibe en un día del fin de semana?', 'Equipo del entrevistador']]
Var_Dep2= df['¿Cuántos clientes, en promedio, recibe en un día entre semana?']
#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model2= LinearRegression()
#Ajustamos el modelo con las variables antes declaradas
model2.fit(X=Vars_Indep2, y=Var_Dep2)

# %%
#Verificamos los coeficientes obtenidos para el modelo ajustado
model2.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['¿Cuántos clientes, en promedio, recibe en un día del fin de semana?',
#         'Equipo del entrevistador'], dtype=object),
#  'n_features_in_': 2,
#  'coef_': array([0.49370318, 0.60119833]),
#  'rank_': 2,
#  'singular_': array([1746.20955812,   47.26944532]),
#  'intercept_': 12.17854350796135}

# %%
#Predecimos los valores de total de accidentes a partir de las variables: "alcohol", "speeding" y "no_previous"
y_pred2= model2.predict(X=df[['¿Cuántos clientes, en promedio, recibe en un día del fin de semana?', 'Equipo del entrevistador']])
#y_pred1
#Insertamos la columna de predicciones en el DataFrame
df.insert(0, 'Predicciones2', y_pred2)
#df

# %% [markdown]
# DATO 3

# %%
sns.scatterplot(x='¿Cuántos clientes, en promedio, recibe en un día entre semana?', y='¿Cuántos clientes, en promedio, recibe en un día del fin de semana?', color="blue", data=df)
sns.scatterplot(x='En una escala de 1 a 10, ¿cómo evaluaría sus esfuerzos para reducir su impacto ambiental?', y='¿Cuántos clientes, en promedio, recibe en un día del fin de semana?', color="red", data=df)

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep3= df[['¿Cuántos clientes, en promedio, recibe en un día entre semana?','En una escala de 1 a 10, ¿cómo evaluaría sus esfuerzos para reducir su impacto ambiental?']]
Var_Dep3= df['¿Cuántos clientes, en promedio, recibe en un día del fin de semana?']
#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model3= LinearRegression()
#Ajustamos el modelo con las variables antes declaradas
model3.fit(X=Vars_Indep3, y=Var_Dep3)

#Verificamos los coeficientes obtenidos para el modelo ajustado
model3.__dict__

#Predecimos los valores de total de accidentes a partir de las variables: "alcohol", "speeding" y "no_previous"
y_pred3= model3.predict(X=df[['¿Cuántos clientes, en promedio, recibe en un día entre semana?','En una escala de 1 a 10, ¿cómo evaluaría sus esfuerzos para reducir su impacto ambiental?']])
#y_pred1
#Insertamos la columna de predicciones en el DataFrame
df.insert(0, 'Predicciones3', y_pred3)
#df

# %%
#Verificamos los coeficientes obtenidos para el modelo ajustado
model3.__dict__

# %%
#Predecimos los valores de total de accidentes a partir de las variables: "alcohol", "speeding" y "no_previous"
y_pred3= model3.predict(X=df[['¿Cuántos clientes, en promedio, recibe en un día entre semana?','En una escala de 1 a 10, ¿cómo evaluaría sus esfuerzos para reducir su impacto ambiental?']])
#y_pred1
#Insertamos la columna de predicciones en el DataFrame
df.insert(0, 'Predicciones3', y_pred3)
#df

# %% [markdown]
# DATO 4

# %%
sns.scatterplot(x='¿Cuántos clientes, en promedio, recibe en un día entre semana?', y='¿Cuántos productos aproximadamente maneja en su tienda?', color="blue", data=df)
sns.scatterplot(x='¿Cuántos clientes, en promedio, recibe en un día del fin de semana?', y='¿Cuántos productos aproximadamente maneja en su tienda?', color="red", data=df)

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep4= df[['¿Cuántos clientes, en promedio, recibe en un día entre semana?','¿Cuántos clientes, en promedio, recibe en un día del fin de semana?']]
Var_Dep4= df['¿Cuántos productos aproximadamente maneja en su tienda?']
#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model4= LinearRegression()
#Ajustamos el modelo con las variables antes declaradas
model4.fit(X=Vars_Indep4, y=Var_Dep4)

#Verificamos los coeficientes obtenidos para el modelo ajustado
model4.__dict__

#Predecimos los valores de total de accidentes a partir de las variables: "alcohol", "speeding" y "no_previous"
y_pred4= model4.predict(X=df[['¿Cuántos clientes, en promedio, recibe en un día entre semana?','¿Cuántos clientes, en promedio, recibe en un día del fin de semana?']])
#y_pred1
#Insertamos la columna de predicciones en el DataFrame
df.insert(0, 'Predicciones4', y_pred4)
#df

# %%
#Verificamos los coeficientes obtenidos para el modelo ajustado
model4.__dict__

# %%
#Predecimos los valores de total de accidentes a partir de las variables: "alcohol", "speeding" y "no_previous"
y_pred4= model4.predict(X=df[['¿Cuántos clientes, en promedio, recibe en un día entre semana?','¿Cuántos clientes, en promedio, recibe en un día del fin de semana?']])
#y_pred1
#Insertamos la columna de predicciones en el DataFrame
df.insert(0, 'Predicciones4', y_pred4)
#df

# %% [markdown]
# DATO 5

# %%
sns.scatterplot(x='Equipo del entrevistador', y='En caso de tener un sistema de recolección ¿Cada cuánto pasa el camión de la basura por su negocio?', color="blue", data=df)
sns.scatterplot(x='En una escala de 1 a 10, ¿cómo evaluaría sus esfuerzos para reducir su impacto social?', y='En caso de tener un sistema de recolección ¿Cada cuánto pasa el camión de la basura por su negocio?', color="red", data=df)

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep5= df[['Equipo del entrevistador','En una escala de 1 a 10, ¿cómo evaluaría sus esfuerzos para reducir su impacto social?']]
Var_Dep5= df['En caso de tener un sistema de recolección ¿Cada cuánto pasa el camión de la basura por su negocio?']
#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model5= LinearRegression()
#Ajustamos el modelo con las variables antes declaradas
model5.fit(X=Vars_Indep5, y=Var_Dep5)

# %%
#Verificamos los coeficientes obtenidos para el modelo ajustado
model5.__dict__

# %%
#Predecimos los valores de total de accidentes a partir de las variables: "alcohol", "speeding" y "no_previous"
y_pred5= model5.predict(X=df[['Equipo del entrevistador','En una escala de 1 a 10, ¿cómo evaluaría sus esfuerzos para reducir su impacto social?']])
#y_pred1
#Insertamos la columna de predicciones en el DataFrame
df.insert(0, 'Predicciones5', y_pred5)
#df

# %% [markdown]
# DATO 6

# %%
sns.scatterplot(x='En una escala de 1 a 10, ¿cómo evaluaría sus esfuerzos para reducir su impacto social?', y='En una escala de 1 a 10, ¿cómo evaluaría sus esfuerzos para reducir su impacto ambiental?', color="blue", data=df)
sns.scatterplot(x='¿Cuántos clientes, en promedio, recibe en un día del fin de semana?', y='En una escala de 1 a 10, ¿cómo evaluaría sus esfuerzos para reducir su impacto ambiental?', color="red", data=df)

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep6= df[['En una escala de 1 a 10, ¿cómo evaluaría sus esfuerzos para reducir su impacto social?','¿Cuántos clientes, en promedio, recibe en un día del fin de semana?']]
Var_Dep6= df['En una escala de 1 a 10, ¿cómo evaluaría sus esfuerzos para reducir su impacto ambiental?']
#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model6= LinearRegression()
#Ajustamos el modelo con las variables antes declaradas
model6.fit(X=Vars_Indep6, y=Var_Dep6)

# %%
#Verificamos los coeficientes obtenidos para el modelo ajustado
model6.__dict__

# %%
#Predecimos los valores de total de accidentes a partir de las variables: "alcohol", "speeding" y "no_previous"
y_pred6= model6.predict(X=df[['En una escala de 1 a 10, ¿cómo evaluaría sus esfuerzos para reducir su impacto social?','¿Cuántos clientes, en promedio, recibe en un día del fin de semana?']])
#y_pred1
#Insertamos la columna de predicciones en el DataFrame
df.insert(0, 'Predicciones6', y_pred6)
#df

# %% [markdown]
# DATO 7

# %%
sns.scatterplot(x='En una escala de 1 a 10, ¿cómo evaluaría sus esfuerzos para reducir su impacto ambiental?', y='En una escala de 1 a 10, ¿cómo evaluaría sus esfuerzos para reducir su impacto social?', color="blue", data=df)
sns.scatterplot(x='Equipo del entrevistador', y='En una escala de 1 a 10, ¿cómo evaluaría sus esfuerzos para reducir su impacto social?', color="red", data=df)

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep7= df[['En una escala de 1 a 10, ¿cómo evaluaría sus esfuerzos para reducir su impacto ambiental?','Equipo del entrevistador']]
Var_Dep7= df['En una escala de 1 a 10, ¿cómo evaluaría sus esfuerzos para reducir su impacto social?']
#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model7= LinearRegression()
#Ajustamos el modelo con las variables antes declaradas
model7.fit(X=Vars_Indep7, y=Var_Dep7)

# %%
#Verificamos los coeficientes obtenidos para el modelo ajustado
model7.__dict__

# %%
#Predecimos los valores de total de accidentes a partir de las variables: "alcohol", "speeding" y "no_previous"
y_pred7= model7.predict(X=df[['En una escala de 1 a 10, ¿cómo evaluaría sus esfuerzos para reducir su impacto ambiental?','Equipo del entrevistador']])
#y_pred1
#Insertamos la columna de predicciones en el DataFrame
df.insert(0, 'Predicciones7', y_pred7)
#df

# %%
df['Equipo del entrevistador'] = df['Equipo del entrevistador'].astype(float)
df['¿Cuántos clientes, en promedio, recibe en un día entre semana?'] = df['¿Cuántos clientes, en promedio, recibe en un día entre semana?'].astype(float)
df['¿Cuántos clientes, en promedio, recibe en un día del fin de semana?'] = df['¿Cuántos clientes, en promedio, recibe en un día del fin de semana?'].astype(float)
df['¿Cuántos productos aproximadamente maneja en su tienda?'] = df['¿Cuántos productos aproximadamente maneja en su tienda?'].astype(float)
df['En caso de tener un sistema de recolección ¿Cada cuánto pasa el camión de la basura por su negocio?'] = df['En caso de tener un sistema de recolección ¿Cada cuánto pasa el camión de la basura por su negocio?'].astype(float)
df['En una escala de 1 a 10, ¿cómo evaluaría sus esfuerzos para reducir su impacto ambiental?'] = df['En una escala de 1 a 10, ¿cómo evaluaría sus esfuerzos para reducir su impacto ambiental?'].astype(float)
df['En una escala de 1 a 10, ¿cómo evaluaría sus esfuerzos para reducir su impacto social?'] = df['En una escala de 1 a 10, ¿cómo evaluaría sus esfuerzos para reducir su impacto social?'].astype(float)
